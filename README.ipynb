# %% [markdown]
# Kick Starting Microsoft's Movie Future

# %% [markdown]
# _____________________________________________________________________________________________________________________

# %% [markdown]
# The Project & Goals

# %% [markdown]
# _____________________________________________________________________________________________________________________

# %% [markdown]
# Project: Microsoft sees all the big companies creating original video content, and they want to get in on the fun. They have decided to create a new movie studio, but the problem is they don’t know anything about creating movies. They have hired you to help them better understand the movie industry. Your team is charged with doing data analysis and creating a presentation that explores what type of films are currently doing the best at the box office. You must then translate those findings into actionable insights that the CEO can use when deciding what type of films they should be creating.

# %% [markdown]
# The goal of this project is to help Microsoft kick start their future in the movie industry.  This will be done through detailed analysis of historical movie data as well as a presentation that translates the findings into actionable understandings.  We will look at several aspects of the data to ensure that Microsoft gets the best start they can leading them to a lucrative future in the movie market.

# %% [markdown]
# _____________________________________________________________________________________________________________________

# %% [markdown]
# __The Datasets__

# %% [markdown]
# _____________________________________________________________________________________________________________________

# %% [markdown]
# - bom.movie_gross
# - imdb.name.basics
# - imdb.title.akas
# - imdb.title.basics
# - imdb.title.crew
# - imdb.title.principals
# - imdb.title.ratings
# - tmdb.movies
# - tn.movie_budgets

# %% [markdown]
# ______________________________________________________________________________________________________________________

# %% [markdown]
# __The approach that will be used__

# %% [markdown]
# - Use pandas to import and create dictionaries
# - Transfer dictionaries into SQL tables
# - Take needed columns from the respected SQL tables and make new data frames
# - Use pandas to clean the data frames: convert columns to the correct type and eliminate missing values
# - Use pandas, matplotlib, and seaborn to visualize the findings

# %% [markdown]
# _____________________________________________________________________________________________________________________

# %% [markdown]
# __Questions answered__

# %% [markdown]
# ______________________________________________________________________________________________________________________

# %% [markdown]
# # Question 1) What are the top 25 movies with the highest domestic gross?

# %% [markdown]
# The bar graph below illustrates the top 25 highest domestic grossing movies over all.  This is important because it gives us an understanding of what movies have done well in the past and gives us and Microsoft a possible starting point if they are looking for a quick start.

# %% [markdown]
# _____________________________________________________________________________________________________________________

# %% [markdown]
# ![Image](data:image/png;base64,...)

# %% [markdown]
# Q1: Insights/Findings/Recommendations

# %% [markdown]
# Findings

# %% [markdown]
# We can see that the majority of the highest domestically grossing films are movies that are either your traditional super hero films or films tailored to a younger audience.

# %% [markdown]
# Recommendations

# %% [markdown]
# - Focus on films that are similar to this top 25: Super hero films or films for a younger audience.

# %% [markdown]
# Future steps

# %% [markdown]
# - Explore the idea of a new super hero to rival competitors
# - Explore the idea of focusing on the younger audience

# %% [markdown]
# # Question 2) What are the 25 movies with the highest popularity rating?

# %% [markdown]
# In the graph below we are examining the 25 most popular movies.

# %% [markdown]
# ______________________________________________________________________________________________________________________

# %% [markdown]
# Q2: Insights/Findings/Recommendations

# %% [markdown]
# ![Image](data:image/png;base64,...)

# %% [markdown]
# Findings

# %% [markdown]
# We find that we have somewhat similar findings to our last graph.  We can see that our most popular movies again are super hero movies and movies that are tailored to a younger audience.

# %% [markdown]
# Recommendations

# %% [markdown]
# - This furthers my previous recommendation to focus on a new super hero movie as well as movies that are tailored to a younger audience
# - Also to get a potential maximization use both, create a super hero that is specifically tailored to a younger audience

# %% [markdown]
# Future Steps

# %% [markdown]
# # Question 3)  Is there any correlation between popularity and domestic gross?

# %% [markdown]
# Below is a scatter plot with popularity and domestic gross.

# %% [markdown]
# ![Image](data:image/png;base64,...)

# %% [markdown]
# Findings

# %% [markdown]
# After examining this scatter plot, we determined there is a slight correlation between the two values.  There is about a .55 correlation which means for every 1 increment increase in domestic gross there is a little over half of an increment increase for popularity.

# %% [markdown]
# Recommendations

# %% [markdown]
# - While there is not a huge correlation between the two values, they still have a positive correlation upon each other
# - The data shows that a focus on popular and high earning movies will have a high chance of producing a successful movie

# %% [markdown]
# Future steps

# %% [markdown]
# # Question 4) What are the most popular movie genres made?

# %% [markdown]
# The following graph illustrates the most popular movie genres.

# %% [markdown]
# ![Image](data:image/png;base64,...)

# %% [markdown]
# Findings

# %% [markdown]
# The data shows that the most popularly made genres are Drama, which is first, followed by Comedy then Action.

# %% [markdown]
# Recommendations

# %% [markdown]
# - The data shows that there is an over saturation of movies in the Drama genre category
# - Steer clear of movies that would fall into the Drama genre category because although they are being made a lot there were not many in the top 25 of the domestic gross or popularity
# - We recommend you focus on expanding the action and comedy genres
# - Most of the movies in the top 25 of the domestic grossing movies and most popular movies would in fact fall into the Action and Comedy categories; those would be good focal points

# %% [markdown]
# Future steps

# %% [markdown]
#  # Question 5) What genres have been made the most over the last 10 years?

# %% [markdown]
# In the graph below we can see the genres that have been produced the most over the last 10 years.

# %% [markdown]
# ![Image](data:image/png;base64,...)

# %% [markdown]
# Findings

# %% [markdown]
# The graph above depicts the top five most produced movie genres: Animation, Western, Crime, Documentary, and Fantasy.
#
# Despite these being the top five most produced movies genres there appears to be be a drop in the number of movies created within the last decade.

# %% [markdown]
# Recommendations

# %% [markdown]
# - This also futhers the recommendation to focus on super hero movies as well as movies tailored to a younger audience.  That is because those movies would fall into these genre groups such as Animation, Fantasy and possibly Crime
